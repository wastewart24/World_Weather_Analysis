# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=787ff3d7c30ec233d2ceed0ef2c14efe

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_city = city.title()
        city_lat = city_weather['coord']['lat']
        city_lon = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
            
        # Append the city information into the city_data list
        city_data.append({"City": city_city,
        "Lat": city_lat,
        "Lng": city_lon,
        "Max Temp": city_max_temp,
        "Humidity": city_hum,
        "Cloudiness": city_cloud,
        "Wind Speed": city_wind,
        "Country": city_country,
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | miri
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | dongsheng
# Processing Record 7 of Set 1 | sarramea
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | songea
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | tyret pervaya
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | asau
# Processing Record 15 of Set 1 | porbandar
# Processing Record 16 of Set 1 | sovetskiy
# Processing Record 17 of Set 1 | grand gaube
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | opuwo
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | portland
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | pitangui
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | thilogne
# City not found. Skipping...
# Processing Record 29 of Set 1 | matara
# Processing Record 30 of Set 1 | nemuro
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | cam ranh
# Processing Record 37 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | onguday
# Processing Record 44 of Set 1 | pokaran
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 1 | aanekoski
# Processing Record 48 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | hasaki
# Processing Record 1 of Set 2 | koumac
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | henties bay
# Processing Record 4 of Set 2 | camalu
# Processing Record 5 of Set 2 | sarkhej
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 2 | namibe
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | turkistan
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | alpena
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | taltal
# Processing Record 20 of Set 2 | la rioja
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | komsomolskiy
# Processing Record 24 of Set 2 | colares
# Processing Record 25 of Set 2 | narsaq
# Processing Record 26 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 2 | salima
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | biak
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | teknaf
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | saint-augustin
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | rio grande
# Processing Record 39 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | asind
# Processing Record 42 of Set 2 | praya
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | yulara
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | abu kamal
# Processing Record 47 of Set 2 | strezhevoy
# Processing Record 48 of Set 2 | hwange
# Processing Record 49 of Set 2 | moses lake
# Processing Record 50 of Set 2 | port lincoln
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | sorsk
# Processing Record 5 of Set 3 | burica
# City not found. Skipping...
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | bonavista
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | mogadishu
# Processing Record 10 of Set 3 | mehamn
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | moorhead
# Processing Record 15 of Set 3 | celestun
# Processing Record 16 of Set 3 | markovo
# Processing Record 17 of Set 3 | bazna
# Processing Record 18 of Set 3 | wabrzezno
# Processing Record 19 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 3 | port-cartier
# Processing Record 21 of Set 3 | riyadh
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | riberalta
# Processing Record 24 of Set 3 | alberton
# Processing Record 25 of Set 3 | aitape
# Processing Record 26 of Set 3 | sao filipe
# Processing Record 27 of Set 3 | phonhong
# Processing Record 28 of Set 3 | tautira
# Processing Record 29 of Set 3 | north branch
# Processing Record 30 of Set 3 | palmer
# Processing Record 31 of Set 3 | los llanos de aridane
# Processing Record 32 of Set 3 | saint george
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | aklavik
# Processing Record 35 of Set 3 | rawson
# Processing Record 36 of Set 3 | laguna
# Processing Record 37 of Set 3 | pacifica
# Processing Record 38 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 3 | kiama
# Processing Record 40 of Set 3 | mandalgovi
# Processing Record 41 of Set 3 | qaanaaq
# Processing Record 42 of Set 3 | killybegs
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | shimoda
# Processing Record 46 of Set 3 | hauterive
# Processing Record 47 of Set 3 | half moon bay
# Processing Record 48 of Set 3 | niamey
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | kenai
# Processing Record 1 of Set 4 | kurumkan
# Processing Record 2 of Set 4 | zhashkiv
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | dwarka
# Processing Record 5 of Set 4 | aasiaat
# Processing Record 6 of Set 4 | doha
# Processing Record 7 of Set 4 | saskylakh
# Processing Record 8 of Set 4 | antofagasta
# Processing Record 9 of Set 4 | paducah
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 4 | san felipe
# Processing Record 13 of Set 4 | krasnoselkup
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | omboue
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 4 | resistencia
# Processing Record 19 of Set 4 | price
# Processing Record 20 of Set 4 | beaverlodge
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | kaihua
# Processing Record 23 of Set 4 | kapaa
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | santa fe
# Processing Record 26 of Set 4 | rantepao
# Processing Record 27 of Set 4 | pacific grove
# Processing Record 28 of Set 4 | umiray
# Processing Record 29 of Set 4 | coahuayana
# Processing Record 30 of Set 4 | ulaangom
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | parati
# Processing Record 34 of Set 4 | chivay
# Processing Record 35 of Set 4 | kodinsk
# Processing Record 36 of Set 4 | cairo
# Processing Record 37 of Set 4 | awjilah
# Processing Record 38 of Set 4 | fairbanks
# Processing Record 39 of Set 4 | yenagoa
# Processing Record 40 of Set 4 | mazagao
# Processing Record 41 of Set 4 | nizwa
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | malakal
# Processing Record 44 of Set 4 | dobryatino
# Processing Record 45 of Set 4 | palana
# Processing Record 46 of Set 4 | houma
# Processing Record 47 of Set 4 | tessalit
# Processing Record 48 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 4 | payo
# Processing Record 50 of Set 4 | huoqiu
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | banfora
# Processing Record 3 of Set 5 | sarangani
# Processing Record 4 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | tirano
# Processing Record 6 of Set 5 | te anau
# Processing Record 7 of Set 5 | san pedro
# Processing Record 8 of Set 5 | carnarvon
# Processing Record 9 of Set 5 | baruun-urt
# Processing Record 10 of Set 5 | mitu
# Processing Record 11 of Set 5 | pangody
# Processing Record 12 of Set 5 | labuhan
# Processing Record 13 of Set 5 | plouzane
# Processing Record 14 of Set 5 | qaqortoq
# Processing Record 15 of Set 5 | berlevag
# Processing Record 16 of Set 5 | dawlatabad
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | kaka
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | almeirim
# Processing Record 21 of Set 5 | hamilton
# Processing Record 22 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 5 | jega
# Processing Record 24 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 5 | nishihara
# Processing Record 26 of Set 5 | ribeira grande
# Processing Record 27 of Set 5 | sola
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | port augusta
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | mpraeso
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | prince rupert
# Processing Record 36 of Set 5 | ullapool
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | ambon
# Processing Record 39 of Set 5 | erzin
# Processing Record 40 of Set 5 | campestre
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | todos santos
# Processing Record 43 of Set 5 | bilibino
# Processing Record 44 of Set 5 | ambanja
# Processing Record 45 of Set 5 | monrovia
# Processing Record 46 of Set 5 | sechura
# Processing Record 47 of Set 5 | ulladulla
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | college
# Processing Record 50 of Set 5 | iqaluit
# Processing Record 1 of Set 6 | kamenka
# Processing Record 2 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 6 | hanzhong
# Processing Record 4 of Set 6 | belmonte
# Processing Record 5 of Set 6 | shagonar
# Processing Record 6 of Set 6 | never
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | shadegan
# Processing Record 11 of Set 6 | taoudenni
# Processing Record 12 of Set 6 | sijunjung
# Processing Record 13 of Set 6 | sumbawanga
# Processing Record 14 of Set 6 | kita
# Processing Record 15 of Set 6 | hanmer springs
# Processing Record 16 of Set 6 | san carlos de bariloche
# Processing Record 17 of Set 6 | harper
# Processing Record 18 of Set 6 | tabas
# Processing Record 19 of Set 6 | kariba
# Processing Record 20 of Set 6 | tigil
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | tuatapere
# Processing Record 23 of Set 6 | galesburg
# Processing Record 24 of Set 6 | puerto penasco
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | itacoatiara
# Processing Record 27 of Set 6 | talnakh
# Processing Record 28 of Set 6 | kenora
# Processing Record 29 of Set 6 | iquitos
# Processing Record 30 of Set 6 | alofi
# Processing Record 31 of Set 6 | karpogory
# Processing Record 32 of Set 6 | avera
# Processing Record 33 of Set 6 | kyabram
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | moultrie
# Processing Record 36 of Set 6 | acarau
# Processing Record 37 of Set 6 | danilovka
# Processing Record 38 of Set 6 | chuy
# Processing Record 39 of Set 6 | paita
# Processing Record 40 of Set 6 | chhukha
# City not found. Skipping...
# Processing Record 41 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 6 | abha
# Processing Record 44 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 6 | portlethen
# Processing Record 46 of Set 6 | cockburn town
# Processing Record 47 of Set 6 | juneau
# Processing Record 48 of Set 6 | puerto colombia
# Processing Record 49 of Set 6 | talaya
# Processing Record 50 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 7 | vanavara
# Processing Record 2 of Set 7 | bambanglipuro
# Processing Record 3 of Set 7 | yarada
# Processing Record 4 of Set 7 | conceicao do araguaia
# Processing Record 5 of Set 7 | korla
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | arbazh
# Processing Record 8 of Set 7 | hovd
# Processing Record 9 of Set 7 | katsuura
# Processing Record 10 of Set 7 | marsh harbour
# Processing Record 11 of Set 7 | northam
# Processing Record 12 of Set 7 | ahipara
# Processing Record 13 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 7 | leh
# Processing Record 15 of Set 7 | port elizabeth
# Processing Record 16 of Set 7 | gari
# Processing Record 17 of Set 7 | rondonopolis
# Processing Record 18 of Set 7 | beloha
# Processing Record 19 of Set 7 | praia
# Processing Record 20 of Set 7 | kalabo
# Processing Record 21 of Set 7 | shasta lake
# Processing Record 22 of Set 7 | nagothana
# Processing Record 23 of Set 7 | acapulco
# Processing Record 24 of Set 7 | port macquarie
# Processing Record 25 of Set 7 | brae
# Processing Record 26 of Set 7 | olafsvik
# Processing Record 27 of Set 7 | ipilan
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | khachrod
# Processing Record 30 of Set 7 | turukhansk
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | atherton
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | florida
# Processing Record 36 of Set 7 | novouzensk
# Processing Record 37 of Set 7 | beringovskiy
# Processing Record 38 of Set 7 | nara
# Processing Record 39 of Set 7 | satuk
# Processing Record 40 of Set 7 | ca mau
# Processing Record 41 of Set 7 | cachira
# Processing Record 42 of Set 7 | zhezkazgan
# Processing Record 43 of Set 7 | ixtapa
# Processing Record 44 of Set 7 | kerouane
# Processing Record 45 of Set 7 | santa cruz
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | jiuquan
# Processing Record 48 of Set 7 | severo-kurilsk
# Processing Record 49 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 7 | san cristobal
# Processing Record 1 of Set 8 | beyneu
# Processing Record 2 of Set 8 | hirara
# Processing Record 3 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 8 | aykhal
# Processing Record 5 of Set 8 | cartagena del chaira
# Processing Record 6 of Set 8 | taraz
# Processing Record 7 of Set 8 | poum
# Processing Record 8 of Set 8 | kyaikto
# Processing Record 9 of Set 8 | guasdualito
# Processing Record 10 of Set 8 | scarborough
# Processing Record 11 of Set 8 | okato
# Processing Record 12 of Set 8 | fort nelson
# Processing Record 13 of Set 8 | sanary-sur-mer
# Processing Record 14 of Set 8 | makakilo city
# Processing Record 15 of Set 8 | pandan
# Processing Record 16 of Set 8 | norman wells
# Processing Record 17 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 8 | margate
# Processing Record 19 of Set 8 | hambantota
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 8 | alugan
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 8 | praia da vitoria
# Processing Record 26 of Set 8 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 27 of Set 8 | chara
# Processing Record 28 of Set 8 | estacion coahuila
# Processing Record 29 of Set 8 | kuytun
# Processing Record 30 of Set 8 | hastings
# Processing Record 31 of Set 8 | kayasula
# Processing Record 32 of Set 8 | petatlan
# Processing Record 33 of Set 8 | esmeraldas
# Processing Record 34 of Set 8 | rzhaksa
# Processing Record 35 of Set 8 | bolshaya dzhalga
# Processing Record 36 of Set 8 | bay roberts
# Processing Record 37 of Set 8 | vardo
# Processing Record 38 of Set 8 | nouakchott
# Processing Record 39 of Set 8 | gazanjyk
# Processing Record 40 of Set 8 | kailua
# Processing Record 41 of Set 8 | warmbad
# Processing Record 42 of Set 8 | bilina
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | dondo
# Processing Record 45 of Set 8 | formosa
# Processing Record 46 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 8 | kloulklubed
# Processing Record 48 of Set 8 | lodja
# Processing Record 49 of Set 8 | balkanabat
# Processing Record 50 of Set 8 | okhotsk
# Processing Record 1 of Set 9 | yumen
# Processing Record 2 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 9 | vila franca do campo
# Processing Record 4 of Set 9 | bria
# Processing Record 5 of Set 9 | pavda
# City not found. Skipping...
# Processing Record 6 of Set 9 | ketchikan
# Processing Record 7 of Set 9 | san juan
# Processing Record 8 of Set 9 | sanchazi
# Processing Record 9 of Set 9 | damphu
# Processing Record 10 of Set 9 | tuy hoa
# Processing Record 11 of Set 9 | partizanske
# Processing Record 12 of Set 9 | akhtyrskiy
# Processing Record 13 of Set 9 | cerritos
# Processing Record 14 of Set 9 | inca
# Processing Record 15 of Set 9 | marsa matruh
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | sidney
# Processing Record 19 of Set 9 | yar-sale
# Processing Record 20 of Set 9 | abnub
# Processing Record 21 of Set 9 | gobabis
# Processing Record 22 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 9 | santa isabel do rio negro
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | yarensk
# Processing Record 26 of Set 9 | kedrovyy
# Processing Record 27 of Set 9 | zhanaozen
# Processing Record 28 of Set 9 | mount pleasant
# Processing Record 29 of Set 9 | itupiranga
# Processing Record 30 of Set 9 | usinsk
# Processing Record 31 of Set 9 | kayes
# Processing Record 32 of Set 9 | mount darwin
# Processing Record 33 of Set 9 | bhadra
# Processing Record 34 of Set 9 | ardakan
# Processing Record 35 of Set 9 | pangkalanbuun
# Processing Record 36 of Set 9 | umm kaddadah
# Processing Record 37 of Set 9 | santa maria
# Processing Record 38 of Set 9 | chokwe
# Processing Record 39 of Set 9 | lavrentiya
# Processing Record 40 of Set 9 | shelekhov
# Processing Record 41 of Set 9 | sinop
# Processing Record 42 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 43 of Set 9 | nakambala
# Processing Record 44 of Set 9 | port hedland
# Processing Record 45 of Set 9 | baoqing
# Processing Record 46 of Set 9 | nancalabasaan
# City not found. Skipping...
# Processing Record 47 of Set 9 | puerto carreno
# Processing Record 48 of Set 9 | zhuhai
# Processing Record 49 of Set 9 | padang
# Processing Record 50 of Set 9 | camabatela
# Processing Record 1 of Set 10 | saint-joseph
# Processing Record 2 of Set 10 | sinnamary
# Processing Record 3 of Set 10 | viedma
# Processing Record 4 of Set 10 | olinda
# Processing Record 5 of Set 10 | sitka
# Processing Record 6 of Set 10 | qui nhon
# Processing Record 7 of Set 10 | gormi
# City not found. Skipping...
# Processing Record 8 of Set 10 | ypane
# Processing Record 9 of Set 10 | teya
# Processing Record 10 of Set 10 | areosa
# Processing Record 11 of Set 10 | moron
# Processing Record 12 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 10 | camana
# Processing Record 14 of Set 10 | kanniyakumari
# Processing Record 15 of Set 10 | lashio
# Processing Record 16 of Set 10 | da nang
# Processing Record 17 of Set 10 | kashi
# Processing Record 18 of Set 10 | verkhnyaya inta
# Processing Record 19 of Set 10 | vuktyl
# Processing Record 20 of Set 10 | ailigandi
# Processing Record 21 of Set 10 | mayo
# Processing Record 22 of Set 10 | ponta do sol
# Processing Record 23 of Set 10 | mecca
# Processing Record 24 of Set 10 | udachnyy
# Processing Record 25 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | stromness
# Processing Record 27 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 10 | vung tau
# Processing Record 29 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 10 | barra da estiva
# Processing Record 31 of Set 10 | meulaboh
# Processing Record 32 of Set 10 | cabedelo
# Processing Record 33 of Set 10 | muros
# Processing Record 34 of Set 10 | fukue
# Processing Record 35 of Set 10 | singaparna
# Processing Record 36 of Set 10 | hokitika
# Processing Record 37 of Set 10 | kudahuvadhoo
# Processing Record 38 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 10 | husavik
# Processing Record 40 of Set 10 | anadyr
# Processing Record 41 of Set 10 | faya
# Processing Record 42 of Set 10 | villazon
# Processing Record 43 of Set 10 | negrar
# Processing Record 44 of Set 10 | lasa
# Processing Record 45 of Set 10 | codrington
# Processing Record 46 of Set 10 | puerto leguizamo
# Processing Record 47 of Set 10 | forbes
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | kiunga
# Processing Record 50 of Set 10 | flinders
# Processing Record 1 of Set 11 | vallam
# Processing Record 2 of Set 11 | maragheh
# Processing Record 3 of Set 11 | voznesenye
# Processing Record 4 of Set 11 | batagay-alyta
# Processing Record 5 of Set 11 | garchitorena
# Processing Record 6 of Set 11 | novikovo
# Processing Record 7 of Set 11 | luganville
# Processing Record 8 of Set 11 | rocha
# Processing Record 9 of Set 11 | bandarbeyla
# Processing Record 10 of Set 11 | xining
# Processing Record 11 of Set 11 | clarence town
# Processing Record 12 of Set 11 | verkhoyansk
# Processing Record 13 of Set 11 | kalmunai
# Processing Record 14 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 11 | burriana
# Processing Record 16 of Set 11 | bardiyah
# Processing Record 17 of Set 11 | oranjemund
# Processing Record 18 of Set 11 | yen bai
# Processing Record 19 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 20 of Set 11 | shache
# Processing Record 21 of Set 11 | cap malheureux
# Processing Record 22 of Set 11 | russell
# Processing Record 23 of Set 11 | havre-saint-pierre
# Processing Record 24 of Set 11 | tottori
# Processing Record 25 of Set 11 | paso de carrasco
# Processing Record 26 of Set 11 | vao
# Processing Record 27 of Set 11 | grindavik
# Processing Record 28 of Set 11 | uruzgan
# Processing Record 29 of Set 11 | nizhneangarsk
# Processing Record 30 of Set 11 | leshukonskoye
# Processing Record 31 of Set 11 | kantemirovka
# Processing Record 32 of Set 11 | nantucket
# Processing Record 33 of Set 11 | tabou
# Processing Record 34 of Set 11 | pasni
# Processing Record 35 of Set 11 | luba
# Processing Record 36 of Set 11 | cayenne
# Processing Record 37 of Set 11 | evans
# Processing Record 38 of Set 11 | hobyo
# Processing Record 39 of Set 11 | seoul
# Processing Record 40 of Set 11 | vagur
# Processing Record 41 of Set 11 | lamar
# Processing Record 42 of Set 11 | semirom
# Processing Record 43 of Set 11 | redlands
# Processing Record 44 of Set 11 | varkaus
# Processing Record 45 of Set 11 | pirapo
# Processing Record 46 of Set 11 | pimenta bueno
# Processing Record 47 of Set 11 | davenda
# Processing Record 48 of Set 11 | fortuna
# Processing Record 49 of Set 11 | kondinskoye
# Processing Record 50 of Set 11 | nabire
# Processing Record 1 of Set 12 | mount isa
# Processing Record 2 of Set 12 | quatre cocos
# Processing Record 3 of Set 12 | shelburne
# Processing Record 4 of Set 12 | lima
# Processing Record 5 of Set 12 | vershino-shakhtaminskiy
# Processing Record 6 of Set 12 | duartina
# Processing Record 7 of Set 12 | cerro de pasco
# Processing Record 8 of Set 12 | kaeo
# Processing Record 9 of Set 12 | tiksi
# Processing Record 10 of Set 12 | turbat
# Processing Record 11 of Set 12 | helong
# Processing Record 12 of Set 12 | kawalu
# Processing Record 13 of Set 12 | boyolangu
# Processing Record 14 of Set 12 | filingue
# Processing Record 15 of Set 12 | waiouru
# Processing Record 16 of Set 12 | huilong
# Processing Record 17 of Set 12 | lac du bonnet
# Processing Record 18 of Set 12 | rivera
# Processing Record 19 of Set 12 | novopavlovka
# Processing Record 20 of Set 12 | ambilobe
# Processing Record 21 of Set 12 | lakes entrance
# Processing Record 22 of Set 12 | kinshasa
# Processing Record 23 of Set 12 | knysna
# Processing Record 24 of Set 12 | xanlar
# Processing Record 25 of Set 12 | danville
# Processing Record 26 of Set 12 | havelock
# Processing Record 27 of Set 12 | lodwar
# Processing Record 28 of Set 12 | easton
# Processing Record 29 of Set 12 | kang
# Processing Record 30 of Set 12 | polovinnoye
# Processing Record 31 of Set 12 | wonthaggi
# Processing Record 32 of Set 12 | bombay
# Processing Record 33 of Set 12 | pochutla
# Processing Record 34 of Set 12 | kyabe
# Processing Record 35 of Set 12 | adre
# Processing Record 36 of Set 12 | port blair
# Processing Record 37 of Set 12 | soe
# Processing Record 38 of Set 12 | kikwit
# Processing Record 39 of Set 12 | clyde river
# Processing Record 40 of Set 12 | bahia honda
# Processing Record 41 of Set 12 | poya
# Processing Record 42 of Set 12 | jangaon
# Processing Record 43 of Set 12 | corinto
# Processing Record 44 of Set 12 | walvis bay
# Processing Record 45 of Set 12 | mayumba
# Processing Record 46 of Set 12 | camacha
# Processing Record 47 of Set 12 | lebyazhye
# Processing Record 48 of Set 12 | ostrovnoy
# Processing Record 49 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 12 | diamantino
# Processing Record 1 of Set 13 | paamiut
# Processing Record 2 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 13 | kununurra
# Processing Record 4 of Set 13 | bereznik
# Processing Record 5 of Set 13 | montelimar
# Processing Record 6 of Set 13 | vanimo
# Processing Record 7 of Set 13 | belle fourche
# Processing Record 8 of Set 13 | pocao de pedras
# Processing Record 9 of Set 13 | caucaia
# Processing Record 10 of Set 13 | zhuanghe
# Processing Record 11 of Set 13 | sharjah
# Processing Record 12 of Set 13 | svetlogorsk
# Processing Record 13 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 13 | sao jose da coroa grande
# Processing Record 15 of Set 13 | sioux lookout
# Processing Record 16 of Set 13 | maltahohe
# Processing Record 17 of Set 13 | likasi
# Processing Record 18 of Set 13 | ridgecrest
# Processing Record 19 of Set 13 | chifeng
# Processing Record 20 of Set 13 | krasnyy oktyabr
# Processing Record 21 of Set 13 | road town
# Processing Record 22 of Set 13 | yola
# Processing Record 23 of Set 13 | sardinata
# Processing Record 24 of Set 13 | lakshmipur
# Processing Record 25 of Set 13 | atar
# Processing Record 26 of Set 13 | bekovo
# Processing Record 27 of Set 13 | ossora
# Processing Record 28 of Set 13 | dhidhdhoo
# Processing Record 29 of Set 13 | pouebo
# Processing Record 30 of Set 13 | junction city
# Processing Record 31 of Set 13 | guerrero negro
# Processing Record 32 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 13 | eha amufu
# Processing Record 34 of Set 13 | baudh
# Processing Record 35 of Set 13 | elliot lake
# Processing Record 36 of Set 13 | cedar falls
# Processing Record 37 of Set 13 | qianguo
# Processing Record 38 of Set 13 | general pico
# Processing Record 39 of Set 13 | broken hill
# Processing Record 40 of Set 13 | karratha
# Processing Record 41 of Set 13 | taketa
# Processing Record 42 of Set 13 | alyangula
# Processing Record 43 of Set 13 | tecoanapa
# Processing Record 44 of Set 13 | ust-uda
# Processing Record 45 of Set 13 | dengzhou
# Processing Record 46 of Set 13 | pilar
# Processing Record 47 of Set 13 | puerto madero
# Processing Record 48 of Set 13 | cefalu
# Processing Record 49 of Set 13 | hanstholm
# Processing Record 50 of Set 13 | itaobim
# Processing Record 1 of Set 14 | belyy yar
# Processing Record 2 of Set 14 | mastic beach
# Processing Record 3 of Set 14 | lakeside
# Processing Record 4 of Set 14 | rogovatoye
# Processing Record 5 of Set 14 | dumabato
# Processing Record 6 of Set 14 | san joaquin
# Processing Record 7 of Set 14 | gorom-gorom
# Processing Record 8 of Set 14 | porto-vecchio
# Processing Record 9 of Set 14 | kargat
# Processing Record 10 of Set 14 | sawtell
# Processing Record 11 of Set 14 | acajutla
# Processing Record 12 of Set 14 | caborca
# Processing Record 13 of Set 14 | derzhavinsk
# Processing Record 14 of Set 14 | mayor pablo lagerenza
# Processing Record 15 of Set 14 | kupang
# Processing Record 16 of Set 14 | aksay
# Processing Record 17 of Set 14 | hami
# Processing Record 18 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 14 | wajima
# Processing Record 21 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 14 | cururupu
# Processing Record 23 of Set 14 | haines junction
# Processing Record 24 of Set 14 | luanda
# Processing Record 25 of Set 14 | cizre
# Processing Record 26 of Set 14 | progreso
# Processing Record 27 of Set 14 | nesoddtangen
# Processing Record 28 of Set 14 | gurupi
# Processing Record 29 of Set 14 | xiangfan
# Processing Record 30 of Set 14 | yushu
# Processing Record 31 of Set 14 | moro
# Processing Record 32 of Set 14 | swan hill
# Processing Record 33 of Set 14 | honiara
# Processing Record 34 of Set 14 | trincomalee
# Processing Record 35 of Set 14 | riohacha
# Processing Record 36 of Set 14 | kosovska mitrovica
# Processing Record 37 of Set 14 | moose factory
# Processing Record 38 of Set 14 | mukhen
# Processing Record 39 of Set 14 | roma
# Processing Record 40 of Set 14 | gushikawa
# Processing Record 41 of Set 14 | goderich
# Processing Record 42 of Set 14 | tchollire
# Processing Record 43 of Set 14 | calama
# Processing Record 44 of Set 14 | guiren
# Processing Record 45 of Set 14 | safaga
# Processing Record 46 of Set 14 | lerik
# Processing Record 47 of Set 14 | port hardy
# Processing Record 48 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 14 | barranca
# Processing Record 50 of Set 14 | bubaque
# Processing Record 1 of Set 15 | labuan
# Processing Record 2 of Set 15 | okha
# Processing Record 3 of Set 15 | gerede
# Processing Record 4 of Set 15 | huzhou
# Processing Record 5 of Set 15 | monterey
# Processing Record 6 of Set 15 | poronaysk
# Processing Record 7 of Set 15 | baie-comeau
# Processing Record 8 of Set 15 | rakiv lis
# Processing Record 9 of Set 15 | bonthe
# Processing Record 10 of Set 15 | thanyaburi
# Processing Record 11 of Set 15 | evensk
# Processing Record 12 of Set 15 | bilma
# Processing Record 13 of Set 15 | santiago del estero
# Processing Record 14 of Set 15 | pisco
# Processing Record 15 of Set 15 | oranjestad
# Processing Record 16 of Set 15 | basmat
# Processing Record 17 of Set 15 | vallentuna
# Processing Record 18 of Set 15 | jerantut
# Processing Record 19 of Set 15 | sirnak
# Processing Record 20 of Set 15 | ureki
# Processing Record 21 of Set 15 | raga
# Processing Record 22 of Set 15 | williamsport
# Processing Record 23 of Set 15 | tura
# Processing Record 24 of Set 15 | maragogi
# Processing Record 25 of Set 15 | manadhoo
# Processing Record 26 of Set 15 | surt
# Processing Record 27 of Set 15 | concarneau
# Processing Record 28 of Set 15 | huarmey
# Processing Record 29 of Set 15 | chapais
# Processing Record 30 of Set 15 | ilobu
# Processing Record 31 of Set 15 | san jeronimo
# Processing Record 32 of Set 15 | yishui
# Processing Record 33 of Set 15 | fort-shevchenko
# Processing Record 34 of Set 15 | north myrtle beach
# Processing Record 35 of Set 15 | chibombo
# Processing Record 36 of Set 15 | saint-pierre
# Processing Record 37 of Set 15 | tateyama
# Processing Record 38 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 15 | rocky mountain house
# Processing Record 40 of Set 15 | kyra
# Processing Record 41 of Set 15 | bridgend
# Processing Record 42 of Set 15 | uribia
# Processing Record 43 of Set 15 | mount gambier
# Processing Record 44 of Set 15 | aquiraz
# Processing Record 45 of Set 15 | zaysan
# Processing Record 46 of Set 15 | tirat karmel
# Processing Record 47 of Set 15 | anqing
# Processing Record 48 of Set 15 | aden
# Processing Record 49 of Set 15 | tocopilla
# Processing Record 50 of Set 15 | la ronge
# Processing Record 1 of Set 16 | jalu
# Processing Record 2 of Set 16 | tingi
# Processing Record 3 of Set 16 | orcopampa
# Processing Record 4 of Set 16 | matamoros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Avarua -21.2078 -159.7750     78.85        78          75
# 1          Miri   4.4148  114.0089     77.14        94          40
# 2  Punta Arenas -53.1500  -70.9167     39.31        81           0
# 3       Rikitea -23.1203 -134.9692     72.12        84          99
# 4     Dongsheng  39.8161  109.9776     45.32        33          53
# 5      Sarramea -21.6421  165.8452     78.08        76          94
# 6     Jamestown  42.0970  -79.2353     38.84        62           0
# 7        Albany  42.6001  -73.9662     38.05        79          12
# 8        Songea -10.6833   35.6500     64.76        91          43
# 9   Tuktoyaktuk  69.4541 -133.0374     10.40        92         100
#
#    Wind Speed Country
# 0       17.27      CK
# 1        4.61      MY
# 2       17.27      CL
# 3        9.13      PF
# 4       18.81      CN
# 5       10.74      NC
# 6        3.44      US
# 7        3.27      US
# 8        4.88      TZ
# 9       10.36      CA

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_list = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=new_column_list)

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Avarua      CK -21.2078 -159.7750     78.85        78          75
# 1          Miri      MY   4.4148  114.0089     77.14        94          40
# 2  Punta Arenas      CL -53.1500  -70.9167     39.31        81           0
# 3       Rikitea      PF -23.1203 -134.9692     72.12        84          99
# 4     Dongsheng      CN  39.8161  109.9776     45.32        33          53
# 5      Sarramea      NC -21.6421  165.8452     78.08        76          94
# 6     Jamestown      US  42.0970  -79.2353     38.84        62           0
# 7        Albany      US  42.6001  -73.9662     38.05        79          12
# 8        Songea      TZ -10.6833   35.6500     64.76        91          43
# 9   Tuktoyaktuk      CA  69.4541 -133.0374     10.40        92         100
#
#    Wind Speed
# 0       17.27
# 1        4.61
# 2       17.27
# 3        9.13
# 4       18.81
# 5       10.74
# 6        3.44
# 7        3.27
# 8        4.88
# 9       10.36

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
