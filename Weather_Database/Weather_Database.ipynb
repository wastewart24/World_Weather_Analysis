# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=787ff3d7c30ec233d2ceed0ef2c14efe

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lon = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
            
        # Append the city information into the city_data list
        city_data.append({"Lat": city_lat,
        "Lng": city_lon,
        "Max Temp": city_max_temp,
        "Humidity": city_hum,
        "Cloudiness": city_cloud,
        "Wind Speed": city_wind,
        "Country": city_country,
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mount isa
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | mandera
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | naze
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | mustafakemalpasa
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | voh
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | burica
# City not found. Skipping...
# Processing Record 22 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | luena
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | henties bay
# Processing Record 27 of Set 1 | zhezkazgan
# Processing Record 28 of Set 1 | pacific grove
# Processing Record 29 of Set 1 | san ignacio
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | nouakchott
# Processing Record 32 of Set 1 | todos santos
# Processing Record 33 of Set 1 | cody
# Processing Record 34 of Set 1 | moisakula
# Processing Record 35 of Set 1 | hofn
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | hay river
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | beloha
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | cugir
# Processing Record 48 of Set 1 | leh
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | escanaba
# Processing Record 1 of Set 2 | nuqui
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | yefira
# City not found. Skipping...
# Processing Record 4 of Set 2 | surt
# Processing Record 5 of Set 2 | fairbanks
# Processing Record 6 of Set 2 | tyukalinsk
# Processing Record 7 of Set 2 | pudozh
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | vendas novas
# Processing Record 10 of Set 2 | nieuw amsterdam
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | tezu
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | lazurne
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | nkhata bay
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | namanga
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | tarko-sale
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | tilichiki
# Processing Record 28 of Set 2 | phon
# Processing Record 29 of Set 2 | chumikan
# Processing Record 30 of Set 2 | morant bay
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | pakxan
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | saint anthony
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | le port
# Processing Record 39 of Set 2 | caravelas
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | karratha
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | homer
# Processing Record 44 of Set 2 | saint-francois
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | turukhansk
# Processing Record 47 of Set 2 | mantua
# Processing Record 48 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | nokaneng
# Processing Record 1 of Set 3 | sarankhola
# Processing Record 2 of Set 3 | puerto madryn
# Processing Record 3 of Set 3 | kondoa
# Processing Record 4 of Set 3 | walvis bay
# Processing Record 5 of Set 3 | bathsheba
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | altay
# Processing Record 8 of Set 3 | asfi
# Processing Record 9 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 10 of Set 3 | estremoz
# Processing Record 11 of Set 3 | calvinia
# Processing Record 12 of Set 3 | soyo
# Processing Record 13 of Set 3 | altamira
# Processing Record 14 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 3 | aklavik
# Processing Record 16 of Set 3 | atasu
# Processing Record 17 of Set 3 | reconquista
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | tual
# Processing Record 20 of Set 3 | faya
# Processing Record 21 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | kavaratti
# Processing Record 26 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 3 | sakaiminato
# Processing Record 28 of Set 3 | platanos
# Processing Record 29 of Set 3 | qaqortoq
# Processing Record 30 of Set 3 | waingapu
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | jamestown
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | vila franca do campo
# Processing Record 36 of Set 3 | capinopolis
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | tianpeng
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | ishigaki
# Processing Record 41 of Set 3 | whitehaven
# Processing Record 42 of Set 3 | taitung
# Processing Record 43 of Set 3 | teknaf
# Processing Record 44 of Set 3 | sabang
# Processing Record 45 of Set 3 | leningradskiy
# Processing Record 46 of Set 3 | bethel
# Processing Record 47 of Set 3 | jonkoping
# Processing Record 48 of Set 3 | mogadishu
# Processing Record 49 of Set 3 | ust-kuyga
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | awjilah
# Processing Record 2 of Set 4 | chekmagush
# Processing Record 3 of Set 4 | oskarshamn
# Processing Record 4 of Set 4 | great bend
# Processing Record 5 of Set 4 | karasburg
# Processing Record 6 of Set 4 | port hedland
# Processing Record 7 of Set 4 | sankt ingbert
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | lebu
# Processing Record 10 of Set 4 | sandnessjoen
# Processing Record 11 of Set 4 | cortland
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | maloy
# Processing Record 15 of Set 4 | kutno
# Processing Record 16 of Set 4 | fort-shevchenko
# Processing Record 17 of Set 4 | moose factory
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | nanakuli
# Processing Record 21 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | ketchikan
# Processing Record 24 of Set 4 | seoul
# Processing Record 25 of Set 4 | fort nelson
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | bambanglipuro
# Processing Record 28 of Set 4 | maracaju
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | valle de santiago
# Processing Record 31 of Set 4 | requena
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 4 | ribeira grande
# Processing Record 35 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 4 | aden
# Processing Record 37 of Set 4 | karasuk
# Processing Record 38 of Set 4 | tinskoy
# Processing Record 39 of Set 4 | nueva imperial
# Processing Record 40 of Set 4 | kenora
# Processing Record 41 of Set 4 | cabedelo
# Processing Record 42 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | la libertad
# Processing Record 44 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 4 | beira
# Processing Record 46 of Set 4 | salisbury
# Processing Record 47 of Set 4 | new norfolk
# Processing Record 48 of Set 4 | balkhash
# Processing Record 49 of Set 4 | tuktoyaktuk
# Processing Record 50 of Set 4 | coihaique
# Processing Record 1 of Set 5 | bemidji
# Processing Record 2 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | black river
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | yumen
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | svetlyy
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | huaraz
# Processing Record 10 of Set 5 | lander
# Processing Record 11 of Set 5 | mocuba
# Processing Record 12 of Set 5 | greystones
# Processing Record 13 of Set 5 | komsomolskiy
# Processing Record 14 of Set 5 | mecca
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | opuwo
# Processing Record 17 of Set 5 | iralaya
# Processing Record 18 of Set 5 | agua buena
# Processing Record 19 of Set 5 | tieling
# Processing Record 20 of Set 5 | daru
# Processing Record 21 of Set 5 | san benito abad
# Processing Record 22 of Set 5 | baykit
# Processing Record 23 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | vao
# Processing Record 26 of Set 5 | kumluca
# Processing Record 27 of Set 5 | castro
# Processing Record 28 of Set 5 | bernardino de campos
# Processing Record 29 of Set 5 | tshikapa
# Processing Record 30 of Set 5 | port-de-bouc
# Processing Record 31 of Set 5 | santiago de chuco
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | hithadhoo
# Processing Record 34 of Set 5 | wangqing
# Processing Record 35 of Set 5 | tirschenreuth
# Processing Record 36 of Set 5 | namibe
# Processing Record 37 of Set 5 | sur
# Processing Record 38 of Set 5 | ponta delgada
# Processing Record 39 of Set 5 | matagami
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | coahuayana
# Processing Record 42 of Set 5 | luderitz
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | chunskiy
# Processing Record 46 of Set 5 | japura
# Processing Record 47 of Set 5 | areni
# Processing Record 48 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 49 of Set 5 | ilulissat
# Processing Record 50 of Set 5 | grindavik
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | tuy hoa
# Processing Record 3 of Set 6 | chauk
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | kondagaon
# Processing Record 6 of Set 6 | vanimo
# Processing Record 7 of Set 6 | qiongshan
# Processing Record 8 of Set 6 | half moon bay
# Processing Record 9 of Set 6 | vrangel
# Processing Record 10 of Set 6 | camana
# Processing Record 11 of Set 6 | yerbogachen
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | makat
# Processing Record 14 of Set 6 | goderich
# Processing Record 15 of Set 6 | isangel
# Processing Record 16 of Set 6 | farrukhnagar
# Processing Record 17 of Set 6 | isiolo
# Processing Record 18 of Set 6 | udachnyy
# Processing Record 19 of Set 6 | mao
# Processing Record 20 of Set 6 | sulzbach-rosenberg
# Processing Record 21 of Set 6 | ylojarvi
# Processing Record 22 of Set 6 | magadan
# Processing Record 23 of Set 6 | woodward
# Processing Record 24 of Set 6 | ban nahin
# Processing Record 25 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 6 | lethem
# Processing Record 27 of Set 6 | husavik
# Processing Record 28 of Set 6 | xining
# Processing Record 29 of Set 6 | constitucion
# Processing Record 30 of Set 6 | poum
# Processing Record 31 of Set 6 | kontagora
# Processing Record 32 of Set 6 | tura
# Processing Record 33 of Set 6 | san cristobal
# Processing Record 34 of Set 6 | bayan
# Processing Record 35 of Set 6 | saint george
# Processing Record 36 of Set 6 | upernavik
# Processing Record 37 of Set 6 | meulaboh
# Processing Record 38 of Set 6 | conde
# Processing Record 39 of Set 6 | ixtapa
# Processing Record 40 of Set 6 | kishi
# Processing Record 41 of Set 6 | tingi
# Processing Record 42 of Set 6 | nabire
# Processing Record 43 of Set 6 | arari
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | hambantota
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | beringovskiy
# Processing Record 49 of Set 6 | motihari
# Processing Record 50 of Set 6 | payson
# Processing Record 1 of Set 7 | atlantic city
# Processing Record 2 of Set 7 | boa vista
# Processing Record 3 of Set 7 | jalu
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | ayan
# Processing Record 6 of Set 7 | bosaso
# Processing Record 7 of Set 7 | umm lajj
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | zyryanka
# Processing Record 10 of Set 7 | celestun
# Processing Record 11 of Set 7 | sayyan
# Processing Record 12 of Set 7 | tazovskiy
# Processing Record 13 of Set 7 | severodvinsk
# Processing Record 14 of Set 7 | santa pola
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | roald
# Processing Record 17 of Set 7 | kaihua
# Processing Record 18 of Set 7 | diffa
# Processing Record 19 of Set 7 | tukrah
# Processing Record 20 of Set 7 | sorong
# Processing Record 21 of Set 7 | korem
# Processing Record 22 of Set 7 | mitzic
# Processing Record 23 of Set 7 | kavieng
# Processing Record 24 of Set 7 | tyukhtet
# Processing Record 25 of Set 7 | honiara
# Processing Record 26 of Set 7 | beian
# Processing Record 27 of Set 7 | brae
# Processing Record 28 of Set 7 | sishui
# Processing Record 29 of Set 7 | pangnirtung
# Processing Record 30 of Set 7 | mangai
# Processing Record 31 of Set 7 | salalah
# Processing Record 32 of Set 7 | roma
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | touros
# Processing Record 35 of Set 7 | wahpeton
# Processing Record 36 of Set 7 | asau
# Processing Record 37 of Set 7 | bourail
# Processing Record 38 of Set 7 | tasiilaq
# Processing Record 39 of Set 7 | acapulco
# Processing Record 40 of Set 7 | sambava
# Processing Record 41 of Set 7 | villagomez
# Processing Record 42 of Set 7 | mayo
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | norrkoping
# Processing Record 45 of Set 7 | canete
# Processing Record 46 of Set 7 | ballina
# Processing Record 47 of Set 7 | paamiut
# Processing Record 48 of Set 7 | cururupu
# Processing Record 49 of Set 7 | saint-philippe
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | high rock
# Processing Record 2 of Set 8 | young
# Processing Record 3 of Set 8 | caiaponia
# Processing Record 4 of Set 8 | ucluelet
# Processing Record 5 of Set 8 | matay
# Processing Record 6 of Set 8 | saurimo
# Processing Record 7 of Set 8 | trairi
# Processing Record 8 of Set 8 | atambua
# Processing Record 9 of Set 8 | zamora
# Processing Record 10 of Set 8 | mackenzie
# Processing Record 11 of Set 8 | canelones
# Processing Record 12 of Set 8 | baruun-urt
# Processing Record 13 of Set 8 | kirakira
# Processing Record 14 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 8 | mahebourg
# Processing Record 16 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 8 | conceicao do araguaia
# Processing Record 18 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 8 | douglas
# Processing Record 20 of Set 8 | charters towers
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | bijar
# Processing Record 23 of Set 8 | burnie
# Processing Record 24 of Set 8 | galveston
# Processing Record 25 of Set 8 | sinop
# Processing Record 26 of Set 8 | dwarka
# Processing Record 27 of Set 8 | buchanan
# Processing Record 28 of Set 8 | eureka
# Processing Record 29 of Set 8 | sobolevo
# Processing Record 30 of Set 8 | carballo
# Processing Record 31 of Set 8 | santa maria
# Processing Record 32 of Set 8 | coquimbo
# Processing Record 33 of Set 8 | hobyo
# Processing Record 34 of Set 8 | monrovia
# Processing Record 35 of Set 8 | gaoual
# Processing Record 36 of Set 8 | cabra
# Processing Record 37 of Set 8 | port moresby
# Processing Record 38 of Set 8 | asilah
# Processing Record 39 of Set 8 | takoradi
# Processing Record 40 of Set 8 | esso
# Processing Record 41 of Set 8 | tromso
# Processing Record 42 of Set 8 | novobelokatay
# Processing Record 43 of Set 8 | christchurch
# Processing Record 44 of Set 8 | treinta y tres
# Processing Record 45 of Set 8 | nacala
# Processing Record 46 of Set 8 | haines junction
# Processing Record 47 of Set 8 | tateyama
# Processing Record 48 of Set 8 | vestmanna
# Processing Record 49 of Set 8 | sibenik
# Processing Record 50 of Set 8 | north bend
# Processing Record 1 of Set 9 | kamphaeng phet
# Processing Record 2 of Set 9 | mastic beach
# Processing Record 3 of Set 9 | san jose
# Processing Record 4 of Set 9 | ikot ekpene
# Processing Record 5 of Set 9 | araguaina
# Processing Record 6 of Set 9 | odweyne
# Processing Record 7 of Set 9 | kaspiyskiy
# Processing Record 8 of Set 9 | seymchan
# Processing Record 9 of Set 9 | katha
# City not found. Skipping...
# Processing Record 10 of Set 9 | ponta do sol
# Processing Record 11 of Set 9 | katangi
# Processing Record 12 of Set 9 | flagstaff
# Processing Record 13 of Set 9 | salinopolis
# Processing Record 14 of Set 9 | oranjemund
# Processing Record 15 of Set 9 | marsa matruh
# Processing Record 16 of Set 9 | agua dulce
# Processing Record 17 of Set 9 | ko samui
# Processing Record 18 of Set 9 | mildura
# Processing Record 19 of Set 9 | isla vista
# Processing Record 20 of Set 9 | zhuhai
# Processing Record 21 of Set 9 | dudinka
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | miyako
# Processing Record 24 of Set 9 | coruripe
# Processing Record 25 of Set 9 | deputatskiy
# Processing Record 26 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 9 | kosovska mitrovica
# Processing Record 28 of Set 9 | saldanha
# Processing Record 29 of Set 9 | ahuimanu
# Processing Record 30 of Set 9 | lima
# Processing Record 31 of Set 9 | hobbs
# Processing Record 32 of Set 9 | trang
# Processing Record 33 of Set 9 | wanaraja
# Processing Record 34 of Set 9 | hanstholm
# Processing Record 35 of Set 9 | ramapuram
# Processing Record 36 of Set 9 | teahupoo
# Processing Record 37 of Set 9 | mbala
# Processing Record 38 of Set 9 | uba
# Processing Record 39 of Set 9 | simbahan
# Processing Record 40 of Set 9 | baherden
# Processing Record 41 of Set 9 | tutoia
# Processing Record 42 of Set 9 | puerto del rosario
# Processing Record 43 of Set 9 | fukuma
# Processing Record 44 of Set 9 | kaduqli
# Processing Record 45 of Set 9 | necochea
# Processing Record 46 of Set 9 | newport
# Processing Record 47 of Set 9 | cosala
# Processing Record 48 of Set 9 | gawler
# Processing Record 49 of Set 9 | muros
# Processing Record 50 of Set 9 | aquiraz
# Processing Record 1 of Set 10 | tortoli
# Processing Record 2 of Set 10 | katherine
# Processing Record 3 of Set 10 | avera
# Processing Record 4 of Set 10 | chemal
# Processing Record 5 of Set 10 | gat
# Processing Record 6 of Set 10 | astana
# Processing Record 7 of Set 10 | portland
# Processing Record 8 of Set 10 | tanjong sepat
# City not found. Skipping...
# Processing Record 9 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 10 | harper
# Processing Record 11 of Set 10 | manzhouli
# Processing Record 12 of Set 10 | kandi
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | klaksvik
# Processing Record 16 of Set 10 | harindanga
# Processing Record 17 of Set 10 | rawson
# Processing Record 18 of Set 10 | mehamn
# Processing Record 19 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 10 | almeria
# Processing Record 21 of Set 10 | axim
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | bereda
# Processing Record 24 of Set 10 | ulan-ude
# Processing Record 25 of Set 10 | lucapa
# Processing Record 26 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 10 | san ramon
# Processing Record 28 of Set 10 | flinders
# Processing Record 29 of Set 10 | chililabombwe
# Processing Record 30 of Set 10 | nome
# Processing Record 31 of Set 10 | bonnyville
# Processing Record 32 of Set 10 | bilma
# Processing Record 33 of Set 10 | havoysund
# Processing Record 34 of Set 10 | wegrow
# Processing Record 35 of Set 10 | aguadilla
# Processing Record 36 of Set 10 | bokoro
# Processing Record 37 of Set 10 | santa vitoria do palmar
# Processing Record 38 of Set 10 | geraldton
# Processing Record 39 of Set 10 | tupik
# Processing Record 40 of Set 10 | puerto quijarro
# Processing Record 41 of Set 10 | batagay
# Processing Record 42 of Set 10 | mahonda
# Processing Record 43 of Set 10 | bandarbeyla
# Processing Record 44 of Set 10 | labuhan
# Processing Record 45 of Set 10 | bhinmal
# Processing Record 46 of Set 10 | campoverde
# Processing Record 47 of Set 10 | chifeng
# Processing Record 48 of Set 10 | san vicente de canete
# Processing Record 49 of Set 10 | sault sainte marie
# Processing Record 50 of Set 10 | severomorsk
# Processing Record 1 of Set 11 | marsh harbour
# Processing Record 2 of Set 11 | airai
# Processing Record 3 of Set 11 | fairview
# Processing Record 4 of Set 11 | niagara falls
# Processing Record 5 of Set 11 | ulaanbaatar
# Processing Record 6 of Set 11 | jiaozuo
# Processing Record 7 of Set 11 | champerico
# Processing Record 8 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 11 | campobasso
# Processing Record 10 of Set 11 | aporawan
# City not found. Skipping...
# Processing Record 11 of Set 11 | santa maria da vitoria
# Processing Record 12 of Set 11 | cap malheureux
# Processing Record 13 of Set 11 | bulanash
# Processing Record 14 of Set 11 | biltine
# Processing Record 15 of Set 11 | meiganga
# Processing Record 16 of Set 11 | santa barbara
# Processing Record 17 of Set 11 | kula
# Processing Record 18 of Set 11 | erdenet
# Processing Record 19 of Set 11 | inuvik
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | general roca
# Processing Record 22 of Set 11 | czechowice-dziedzice
# Processing Record 23 of Set 11 | khilok
# Processing Record 24 of Set 11 | havre-saint-pierre
# Processing Record 25 of Set 11 | sechura
# Processing Record 26 of Set 11 | faanui
# Processing Record 27 of Set 11 | bongandanga
# Processing Record 28 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 11 | chute-aux-outardes
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | palestine
# Processing Record 32 of Set 11 | nishihara
# Processing Record 33 of Set 11 | nicoya
# Processing Record 34 of Set 11 | dinar
# Processing Record 35 of Set 11 | lewistown
# Processing Record 36 of Set 11 | nantucket
# Processing Record 37 of Set 11 | ambon
# Processing Record 38 of Set 11 | trelew
# Processing Record 39 of Set 11 | noyabrsk
# Processing Record 40 of Set 11 | stykkisholmur
# Processing Record 41 of Set 11 | novyy urengoy
# Processing Record 42 of Set 11 | emet
# Processing Record 43 of Set 11 | kieta
# Processing Record 44 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 11 | isabela
# Processing Record 46 of Set 11 | concepcion
# Processing Record 47 of Set 11 | shirgaon
# Processing Record 48 of Set 11 | cayenne
# Processing Record 49 of Set 11 | sandwick
# Processing Record 50 of Set 11 | iracoubo
# Processing Record 1 of Set 12 | narasannapeta
# Processing Record 2 of Set 12 | road town
# Processing Record 3 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 12 | san rafael
# Processing Record 5 of Set 12 | grand forks
# Processing Record 6 of Set 12 | mananjary
# Processing Record 7 of Set 12 | shitanjing
# Processing Record 8 of Set 12 | mackay
# Processing Record 9 of Set 12 | kayerkan
# Processing Record 10 of Set 12 | port-gentil
# Processing Record 11 of Set 12 | honningsvag
# Processing Record 12 of Set 12 | muyezerskiy
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | salina cruz
# Processing Record 15 of Set 12 | oum hadjer
# Processing Record 16 of Set 12 | krasnoarmeysk
# Processing Record 17 of Set 12 | bassano
# Processing Record 18 of Set 12 | padang
# Processing Record 19 of Set 12 | alekseyevsk
# Processing Record 20 of Set 12 | kibala
# Processing Record 21 of Set 12 | la rioja
# Processing Record 22 of Set 12 | wanaka
# Processing Record 23 of Set 12 | pathein
# Processing Record 24 of Set 12 | yaounde
# Processing Record 25 of Set 12 | berlevag
# Processing Record 26 of Set 12 | mareeba
# Processing Record 27 of Set 12 | termoli
# Processing Record 28 of Set 12 | acaponeta
# Processing Record 29 of Set 12 | antigonish
# Processing Record 30 of Set 12 | wanning
# Processing Record 31 of Set 12 | pouebo
# Processing Record 32 of Set 12 | oga
# Processing Record 33 of Set 12 | banda aceh
# Processing Record 34 of Set 12 | singaraja
# Processing Record 35 of Set 12 | manica
# Processing Record 36 of Set 12 | rongcheng
# Processing Record 37 of Set 12 | marmaron
# City not found. Skipping...
# Processing Record 38 of Set 12 | sioux lookout
# Processing Record 39 of Set 12 | niksic
# Processing Record 40 of Set 12 | vostok
# Processing Record 41 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 12 | sao filipe
# Processing Record 43 of Set 12 | egvekinot
# Processing Record 44 of Set 12 | lincoln
# Processing Record 45 of Set 12 | caucaia
# Processing Record 46 of Set 12 | limbang
# Processing Record 47 of Set 12 | auki
# Processing Record 48 of Set 12 | kangalassy
# Processing Record 49 of Set 12 | bilibino
# Processing Record 50 of Set 12 | saint-denis
# Processing Record 1 of Set 13 | manono
# Processing Record 2 of Set 13 | port blair
# Processing Record 3 of Set 13 | kastamonu
# Processing Record 4 of Set 13 | pontecorvo
# Processing Record 5 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 13 | ozernovskiy
# Processing Record 7 of Set 13 | evensk
# Processing Record 8 of Set 13 | demir kapija
# Processing Record 9 of Set 13 | matadi
# Processing Record 10 of Set 13 | zhovtneve
# Processing Record 11 of Set 13 | yarada
# Processing Record 12 of Set 13 | ndele
# Processing Record 13 of Set 13 | college
# Processing Record 14 of Set 13 | kloulklubed
# Processing Record 15 of Set 13 | dingle
# Processing Record 16 of Set 13 | manakara
# Processing Record 17 of Set 13 | griffith
# Processing Record 18 of Set 13 | jilmah
# City not found. Skipping...
# Processing Record 19 of Set 13 | sisimiut
# Processing Record 20 of Set 13 | jingdezhen
# Processing Record 21 of Set 13 | oistins
# Processing Record 22 of Set 13 | makinsk
# Processing Record 23 of Set 13 | lobito
# Processing Record 24 of Set 13 | sompeta
# Processing Record 25 of Set 13 | lenine
# Processing Record 26 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 13 | akcakoca
# Processing Record 28 of Set 13 | mahon
# Processing Record 29 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 13 | macrohon
# Processing Record 31 of Set 13 | yebaishou
# Processing Record 32 of Set 13 | moshenskoye
# Processing Record 33 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 13 | alzamay
# Processing Record 35 of Set 13 | cortes
# Processing Record 36 of Set 13 | neuquen
# Processing Record 37 of Set 13 | dakar
# Processing Record 38 of Set 13 | esil
# Processing Record 39 of Set 13 | uray
# Processing Record 40 of Set 13 | humboldt
# Processing Record 41 of Set 13 | gamba
# Processing Record 42 of Set 13 | bonavista
# Processing Record 43 of Set 13 | wagar
# Processing Record 44 of Set 13 | murgab
# Processing Record 45 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 13 | milas
# Processing Record 47 of Set 13 | pocatello
# Processing Record 48 of Set 13 | tanabi
# Processing Record 49 of Set 13 | mustasaari
# Processing Record 50 of Set 13 | zambezi
# Processing Record 1 of Set 14 | lasa
# Processing Record 2 of Set 14 | birobidzhan
# Processing Record 3 of Set 14 | livingston
# Processing Record 4 of Set 14 | invermere
# Processing Record 5 of Set 14 | gewane
# Processing Record 6 of Set 14 | mayor pablo lagerenza
# Processing Record 7 of Set 14 | talcahuano
# Processing Record 8 of Set 14 | sasebo
# Processing Record 9 of Set 14 | emirdag
# Processing Record 10 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 14 | maarianhamina
# Processing Record 12 of Set 14 | siguiri
# Processing Record 13 of Set 14 | jiuquan
# Processing Record 14 of Set 14 | erenhot
# Processing Record 15 of Set 14 | srandakan
# Processing Record 16 of Set 14 | hualmay
# Processing Record 17 of Set 14 | talnakh
# Processing Record 18 of Set 14 | monroe
# Processing Record 19 of Set 14 | muravlenko
# Processing Record 20 of Set 14 | palamos
# Processing Record 21 of Set 14 | rio grande
# Processing Record 22 of Set 14 | koumac
# Processing Record 23 of Set 14 | kindu
# Processing Record 24 of Set 14 | ferndale
# Processing Record 25 of Set 14 | leshan
# Processing Record 26 of Set 14 | izazi
# Processing Record 27 of Set 14 | molochnoye
# Processing Record 28 of Set 14 | almirante
# Processing Record 29 of Set 14 | high level
# Processing Record 30 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 14 | waipawa
# Processing Record 32 of Set 14 | manado
# Processing Record 33 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 14 | potoru
# Processing Record 35 of Set 14 | xai-xai
# Processing Record 36 of Set 14 | bojonegoro
# Processing Record 37 of Set 14 | buchrain
# Processing Record 38 of Set 14 | itarsi
# Processing Record 39 of Set 14 | sao joao da barra
# Processing Record 40 of Set 14 | colares
# Processing Record 41 of Set 14 | nanortalik
# Processing Record 42 of Set 14 | zyryanskoye
# Processing Record 43 of Set 14 | kemijarvi
# Processing Record 44 of Set 14 | peremyshl
# Processing Record 45 of Set 14 | puerto leguizamo
# Processing Record 46 of Set 14 | juneau
# Processing Record 47 of Set 14 | poltavka
# Processing Record 48 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 49 of Set 14 | senneterre
# Processing Record 50 of Set 14 | lata
# Processing Record 1 of Set 15 | ambilobe
# Processing Record 2 of Set 15 | adrar
# Processing Record 3 of Set 15 | palmer
# Processing Record 4 of Set 15 | bowen
# Processing Record 5 of Set 15 | chunar
# Processing Record 6 of Set 15 | black diamond
# Processing Record 7 of Set 15 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 8 of Set 15 | kurtamysh
# Processing Record 9 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 15 | pangai
# Processing Record 11 of Set 15 | oksfjord
# Processing Record 12 of Set 15 | dukat
# Processing Record 13 of Set 15 | alice springs
# Processing Record 14 of Set 15 | mandalgovi
# Processing Record 15 of Set 15 | saravan
# Processing Record 16 of Set 15 | keti bandar
# Processing Record 17 of Set 15 | kokopo
# Processing Record 18 of Set 15 | bahia de caraquez
# Processing Record 19 of Set 15 | moron
# Processing Record 20 of Set 15 | okhotsk
# Processing Record 21 of Set 15 | imbituba
# Processing Record 22 of Set 15 | anori
# Processing Record 23 of Set 15 | buraydah
# Processing Record 24 of Set 15 | kearney
# Processing Record 25 of Set 15 | urengoy
# Processing Record 26 of Set 15 | urumqi
# Processing Record 27 of Set 15 | oliveira dos brejinhos
# Processing Record 28 of Set 15 | deskati
# Processing Record 29 of Set 15 | dawei
# Processing Record 30 of Set 15 | umarizal
# Processing Record 31 of Set 15 | trat
# Processing Record 32 of Set 15 | boyolangu
# Processing Record 33 of Set 15 | dakoro
# Processing Record 34 of Set 15 | tadine
# Processing Record 35 of Set 15 | caruray
# Processing Record 36 of Set 15 | maua
# Processing Record 37 of Set 15 | moranbah
# Processing Record 38 of Set 15 | vila
# Processing Record 39 of Set 15 | aksarka
# Processing Record 40 of Set 15 | hutchinson
# Processing Record 41 of Set 15 | innisfail
# Processing Record 42 of Set 15 | markapur
# Processing Record 43 of Set 15 | salekhard
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#        Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country
# 0  27.9769 -114.0611     57.85        63           0        5.39      MX
# 1 -54.8000  -68.3000     55.02        40          40       14.97      AR
# 2 -20.7333  139.5000     73.17        60           0        0.00      AU
# 3 -23.1203 -134.9692     71.28        71          95       13.24      PF
# 4  19.7297 -155.0900     74.25        84          40        6.91      US
# 5   3.9366   41.8670     91.49        37          32        3.80      KE
# 6 -46.2817  169.8464     53.92        98         100        8.95      NZ
# 7  28.3667  129.4833     72.52        89          57       13.35      JP
# 8 -33.9180   25.5701     71.89        64          20       12.66      ZA
# 9 -33.6500  115.3333     53.46        65          95       10.78      AU

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed',
#        'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_list = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=new_column_list)

# Display sample data
city_data_df.head(10)
# Out:
#    City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   NaN      MX  27.9769 -114.0611     57.85        63           0        5.39
# 1   NaN      AR -54.8000  -68.3000     55.02        40          40       14.97
# 2   NaN      AU -20.7333  139.5000     73.17        60           0        0.00
# 3   NaN      PF -23.1203 -134.9692     71.28        71          95       13.24
# 4   NaN      US  19.7297 -155.0900     74.25        84          40        6.91
# 5   NaN      KE   3.9366   41.8670     91.49        37          32        3.80
# 6   NaN      NZ -46.2817  169.8464     53.92        98         100        8.95
# 7   NaN      JP  28.3667  129.4833     72.52        89          57       13.35
# 8   NaN      ZA -33.9180   25.5701     71.89        64          20       12.66
# 9   NaN      AU -33.6500  115.3333     53.46        65          95       10.78

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City          float64
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
